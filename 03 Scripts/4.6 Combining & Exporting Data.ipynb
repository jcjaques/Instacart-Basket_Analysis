# %% [markdown]
# # 4.6 Task

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
# create path
path = r'\Users\jeffr\Documents\Instacart Basket Analysis'

# %%
# Importing orders_products_combined.pkl
orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# Checking shape
orders_products_combined.shape
# Out:
# (32434489, 13)

# %%
# Checking dataframe columns
orders_products_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             0           0   2539329        1    prior             1
# 2             0           0   2539329        1    prior             1
# 3             0           0   2539329        1    prior             1
# 4             0           0   2539329        1    prior             1
#
#    orders_day_of_week  order_time_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   2                  8                     NaN       14084
# 2                   2                  8                     NaN       12427
# 3                   2                  8                     NaN       26088
# 4                   2                  8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# ...

# %%
# Importing products_checked.csv
products_checked = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
# Checking shape
products_checked.shape
# Out:
# (49672, 6)

# %%
# Checking dataframe columns
products_checked.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# It appears both dataframes had the product_id column. 
df_ords_prod_merge = orders_products_combined.merge(products_checked, on = 'product_id', indicator = 'match')

# %%
df_ords_prod_merge.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0             0             0   2539329        1    prior             1
# 1             0             0   2539329        1    prior             1
# 2             0             0   2539329        1    prior             1
# 3             0             0   2539329        1    prior             1
# 4             0             0   2539329        1    prior             1
#
#    orders_day_of_week  order_time_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   2                  8                     NaN       14084
# 2                   2                  8                     NaN       12427
# 3                   2                  8                     NaN       26088
# 4                   2                  8                     NaN       26405
#
#    add_to_cart_order  reordered _merge  Unnamed: 0_y  \
# ...

# %%
df_ords_prod_merge.shape
# Out:
# (32404859, 19)

# %%
df_ords_prod_merge['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# Exporting dataframe as pkl
df_ords_prod_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))
